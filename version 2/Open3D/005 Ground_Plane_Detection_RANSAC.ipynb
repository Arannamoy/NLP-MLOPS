# %% [markdown]
# #### RANSAC Algorithm
#
# ```
#    Random 3 Points
#         │
#         ▼
#     Build Plane
#         │
#         ▼
#     Count Inliers
#         │
#         ▼
#       Repeat
#         │
#         ▼
#     Best Plane
# ```
