# %% [markdown]
# ### What is decision tree?
# - a predictive model that makes classifications

# %% [markdown]
# ### Why decision tree?
# - Simple and intuitive
# - Easy to visualize
# - Versatile data handling
# - Minimal processing
