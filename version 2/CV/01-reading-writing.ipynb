# %%
import cv2

# %%
# %ls Images
# Out:
#  BGR2GRAY_OUTPUT.png
#  BGR2HSV_OUTPUT.png
#  BGR2LAB_OUTPUT.png
#  BGR2RGB_OUTPUT.png
# 'Connection between Scikit Image, Open CV, Pillow, TF,Torch, YOLO copy.png'*
#  green_mamba1.jpeg
#  image_new.png
#  Pandas.png
#  test.png*

# %%
image=cv2.imread("Images/Connection between Scikit Image, Open CV, Pillow, TF,Torch, YOLO copy.png")

# %%
print(type(image))
# Out:
# <class 'numpy.ndarray'>

# %%
image.shape
# Out:
# (922, 1698, 3)

# %%
image=image+30

# %%
cv2.imshow("Connection between Scikit Image, Open CV, Pillow, TF,Torch, YOLO copy",image)
cv2.waitKey(0)
cv2.destroyAllWindows()
