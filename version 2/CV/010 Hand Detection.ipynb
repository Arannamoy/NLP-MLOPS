# %%
import cv2
from cvzone.HandTrackingModule import HandDetector

# %%
detector=HandDetector(detectionCon=0.9,maxHands=100)
# Out:
# I0000 00:00:1782361982.858466   32092 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1782361982.859988   32128 gl_context.cc:385] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.2.8-0ubuntu0.24.04.2), renderer: Mesa Intel(R) Graphics (RPL-S)
# W0000 00:00:1782361982.876599   32097 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1782361982.885218   32114 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
video=cv2.VideoCapture(1)
while True:
    res,frame=video.read()
    if not res:
        break
    hands,frame=detector.findHands(frame)
    if hands:
        lmList=hands[0]["lmList"]
        handType=hands[0]['type']
    cv2.imshow("Hand detection",frame)
    if cv2.waitKey(1) & 0xFF==ord('q'):
        break
video.release()
cv2.destroyAllWindows()
