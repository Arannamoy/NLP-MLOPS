# %%
import cv2
from cvzone.PoseModule import PoseDetector
from cvzone.Utils import stackImages

# %%
detector=PoseDetector(modelComplexity=1)
# Out:
# I0000 00:00:1782362774.067126   34190 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1782362774.069019   34226 gl_context.cc:385] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.2.8-0ubuntu0.24.04.2), renderer: Mesa Intel(R) Graphics (RPL-S)
# W0000 00:00:1782362774.106237   34205 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1782362774.119723   34209 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
video=cv2.VideoCapture(1)

while True:
    res,frame=video.read()

    if not res:
        break
    frame=detector.findPose(frame)
    lmList,bboxes=detector.findPosition(frame)
    cv2.namedWindow("Pose Detection", cv2.WINDOW_NORMAL)
    cv2.imshow("Pose Detection",frame)
    
    if cv2.waitKey(1) & 0xFF==ord('q'):
        break

video.release()
cv2.destroyAllWindows()
