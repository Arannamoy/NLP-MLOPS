# %%
# !pip install mediapipe
# Out:
# Requirement already satisfied: mediapipe in /home/workstation-p/anaconda3/envs/conda-env-mlops-3-12/lib/python3.12/site-packages (0.10.35)
# Requirement already satisfied: absl-py~=2.3 in /home/workstation-p/anaconda3/envs/conda-env-mlops-3-12/lib/python3.12/site-packages (from mediapipe) (2.4.0)
# Requirement already satisfied: certifi in /home/workstation-p/anaconda3/envs/conda-env-mlops-3-12/lib/python3.12/site-packages (from mediapipe) (2026.4.22)
# Requirement already satisfied: numpy in /home/workstation-p/anaconda3/envs/conda-env-mlops-3-12/lib/python3.12/site-packages (from mediapipe) (2.4.5)
# Requirement already satisfied: sounddevice~=0.5 in /home/workstation-p/anaconda3/envs/conda-env-mlops-3-12/lib/python3.12/site-packages (from mediapipe) (0.5.5)
# Requirement already satisfied: flatbuffers~=25.9 in /home/workstation-p/anaconda3/envs/conda-env-mlops-3-12/lib/python3.12/site-packages (from mediapipe) (25.12.19)
# Requirement already satisfied: opencv-contrib-python in /home/workstation-p/anaconda3/envs/conda-env-mlops-3-12/lib/python3.12/site-packages (from mediapipe) (4.13.0.92)
# Requirement already satisfied: matplotlib in /home/workstation-p/anaconda3/envs/conda-env-mlops-3-12/lib/python3.12/site-packages (from mediapipe) (3.10.8)
# Requirement already satisfied: cffi in /home/workstation-p/anaconda3/envs/conda-env-mlops-3-12/lib/python3.12/site-packages (from sounddevice~=0.5->mediapipe) (2.0.0)
# Requirement already satisfied: pycparser in /home/workstation-p/anaconda3/envs/conda-env-mlops-3-12/lib/python3.12/site-packages (from cffi->sounddevice~=0.5->mediapipe) (3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/workstation-p/anaconda3/envs/conda-env-mlops-3-12/lib/python3.12/site-packages (from matplotlib->mediapipe) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/workstation-p/anaconda3/envs/conda-env-mlops-3-12/lib/python3.12/site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/workstation-p/anaconda3/envs/conda-env-mlops-3-12/lib/python3.12/site-packages (from matplotlib->mediapipe) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/workstation-p/anaconda3/envs/conda-env-mlops-3-12/lib/python3.12/site-packages (from matplotlib->mediapipe) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/workstation-p/anaconda3/envs/conda-env-mlops-3-12/lib/python3.12/site-packages (from matplotlib->mediapipe) (26.2)
# Requirement already satisfied: pillow>=8 in /home/workstation-p/anaconda3/envs/conda-env-mlops-3-12/lib/python3.12/site-packages (from matplotlib->mediapipe) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /home/workstation-p/anaconda3/envs/conda-env-mlops-3-12/lib/python3.12/site-packages (from matplotlib->mediapipe) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/workstation-p/anaconda3/envs/conda-env-mlops-3-12/lib/python3.12/site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/workstation-p/anaconda3/envs/conda-env-mlops-3-12/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)

# %%
import cv2
from cvzone.FaceDetectionModule import FaceDetector

# %%
detector=FaceDetector()
# Out:
# Downloading MediaPipe Face Model...
# Download Complete.
# I0000 00:00:1782361667.196968   31120 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1782361667.198985   31138 gl_context.cc:385] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.2.8-0ubuntu0.24.04.2), renderer: Mesa Intel(R) Graphics (RPL-S)
# W0000 00:00:1782361667.201101   31123 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
video=cv2.VideoCapture(1)
while True:
    res,frame=video.read()
    if not res:
        break
    frame,bboxes=detector.findFaces(frame)
    if bboxes:
        center=bboxes[0]
    cv2.imshow("Face Detection",frame)
    if cv2.waitKey(1) & 0xFF==ord('q'):
        break
video.release()
cv2.destroyAllWindows()
