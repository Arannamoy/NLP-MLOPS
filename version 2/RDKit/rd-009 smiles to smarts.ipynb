# %%
from rdkit import Chem

# %%
mol=Chem.MolFromSmiles("CCO")
smarts=Chem.MolToSmarts(mol)
print(smarts)
# Out:
# [#6]-[#6]-[#8]

# %%
smarts=Chem.MolFromSmarts(smarts)


for atom in smarts.GetAtoms():
    print(atom.DescribeQuery())
# Out:
# AtomAtomicNum 6 = val
#
# AtomAtomicNum 6 = val
#
# AtomAtomicNum 8 = val
