# %%
from torchdrug import data
import matplotlib
# %matplotlib inline

# %%
smiles='C1=[C]NC=C1'
mol=data.Molecule.from_smiles(smiles)
mol.visualize()

# %%
smiles=["C1=[C]NC=C1","C[C]#C[C]"]
mols=data.PackedMolecule.from_smiles(smiles)
mols.visualize()
