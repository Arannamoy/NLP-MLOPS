# %%
from rdkit import Chem
import cirpy

# %%
smiles=cirpy.resolve("ethanol","smiles")
print(smiles)
# Out:
# CCO

# %%
mol=Chem.MolFromSmiles(smiles)
smarts=Chem.MolToSmarts(mol)

# %%
smarts
# Out:
# '[#6]-[#6]-[#8]'

# %% [markdown]
# #### Start from here

# %%
mol=Chem.MolFromSmarts(smarts)

# %%
smiles=Chem.MolToSmiles(mol)

# %%
print(smiles)
# Out:
# CCO
