# %%
from rdkit import Chem

# %%
print(Chem.AtomFromSmarts('[H,Cl]').DescribeQuery())
# Out:
# AtomOr
#   AtomHCount 1 = val
#   AtomType 17 = val

# %%
print(Chem.AtomFromSmarts('[2H+]').DescribeQuery())
# Out:
# AtomAnd
#   AtomAnd
#     AtomAtomicNum 1 = val
#     AtomIsotope 2 = val
#   AtomFormalCharge 1 = val

# %%
print(Chem.AtomFromSmarts('[C,O,H,CO2-]').DescribeQuery())
# Out:
# AtomOr
#   AtomOr
#     AtomOr
#       AtomType 6 = val
#       AtomType 8 = val
#     AtomHCount 1 = val
#   AtomAnd
#     AtomAnd
#       AtomAnd
#         AtomType 6 = val
#         AtomType 8 = val
#       AtomIsotope 2 = val
#     AtomFormalCharge -1 = val
