# %%
from torch_geometric.utils import from_smiles,to_networkx
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=from_smiles("C[C@H](N)C(=O)NCC1=CC=C(C=C1)S(=O)(=O)NCCOP(=O)([O-])OCC[NH3+]")
print(data)
# Out:
# Data(x=[27, 9], edge_index=[2, 54], edge_attr=[54, 3], smiles='C[C@H](N)C(=O)NCC1=CC=C(C=C1)S(=O)(=O)NCCOP(=O)([O-])OCC[NH3+]')

# %%
import networkx as nx
G=to_networkx(data)
nx.draw(G,with_labels=True)

# %%
print(data.size)
# Out:
# <bound method BaseData.size of Data(x=[27, 9], edge_index=[2, 54], edge_attr=[54, 3], smiles='C[C@H](N)C(=O)NCC1=CC=C(C=C1)S(=O)(=O)NCCOP(=O)([O-])OCC[NH3+]')>

# %%
print(data.edge_index)
# Out:
# tensor([[ 0,  1,  1,  1,  2,  3,  3,  3,  4,  5,  5,  6,  6,  7,  7,  7,  8,  8,
#           9,  9, 10, 10, 10, 11, 11, 12, 12, 13, 13, 13, 13, 14, 15, 16, 16, 17,
#          17, 18, 18, 19, 19, 20, 20, 20, 20, 21, 22, 23, 23, 24, 24, 25, 25, 26],
#         [ 1,  0,  2,  3,  1,  1,  4,  5,  3,  3,  6,  5,  7,  6,  8, 12,  7,  9,
#           8, 10,  9, 11, 13, 10, 12,  7, 11, 10, 14, 15, 16, 13, 13, 13, 17, 16,
#          18, 17, 19, 18, 20, 19, 21, 22, 23, 20, 20, 20, 24, 23, 25, 24, 26, 25]])

# %%
print(data.x)
# Out:
# tensor([[ 6,  0,  4,  5,  3,  0,  4,  0,  0],
#         [ 6,  2,  4,  5,  1,  0,  4,  0,  0],
#         [ 7,  0,  3,  5,  2,  0,  4,  0,  0],
#         [ 6,  0,  3,  5,  0,  0,  3,  0,  0],
#         [ 8,  0,  1,  5,  0,  0,  3,  0,  0],
#         [ 7,  0,  3,  5,  1,  0,  3,  0,  0],
#         [ 6,  0,  4,  5,  2,  0,  4,  0,  0],
#         [ 6,  0,  3,  5,  0,  0,  3,  1,  1],
#         [ 6,  0,  3,  5,  1,  0,  3,  1,  1],
#         [ 6,  0,  3,  5,  1,  0,  3,  1,  1],
#         [ 6,  0,  3,  5,  0,  0,  3,  1,  1],
#         [ 6,  0,  3,  5,  1,  0,  3,  1,  1],
#         [ 6,  0,  3,  5,  1,  0,  3,  1,  1],
#         [16,  0,  4,  5,  0,  0,  4,  0,  0],
#         [ 8,  0,  1,  5,  0,  0,  3,  0,  0],
#         [ 8,  0,  1,  5,  0,  0,  3,  0,  0],
#         [ 7,  0,  3,  5,  1,  0,  4,  0,  0],
#         [ 6,  0,  4,  5,  2,  0,  4,  0,  0],
#         [ 6,  0,  4,  5,  2,  0,  4,  0,  0],
#         [ 8,  0,  2,  5,  0,  0,  4,  0,  0],
#         [15,  0,  4,  5,  0,  0,  4,  0,  0],
#         [ 8,  0,  1,  5,  0,  0,  3,  0,  0],
#         [ 8,  0,  1,  4,  0,  0,  4,  0,  0],
#         [ 8,  0,  2,  5,  0,  0,  4,  0,  0],
#         [ 6,  0,  4,  5,  2,  0,  4,  0,  0],
#         [ 6,  0,  4,  5,  2,  0,  4,  0,  0],
#         [ 7,  0,  4,  6,  3,  0,  4,  0,  0]])

# %%
print(data.edge_attrs)
# Out:
# <bound method BaseData.edge_attrs of Data(x=[27, 9], edge_index=[2, 54], edge_attr=[54, 3], smiles='C[C@H](N)C(=O)NCC1=CC=C(C=C1)S(=O)(=O)NCCOP(=O)([O-])OCC[NH3+]')>

# %%
print(data.x.shape)
print(data.edge_index.shape)
print(data.edge_attr.shape)
# Out:
# torch.Size([27, 9])
# torch.Size([2, 54])
# torch.Size([54, 3])
