# %%
# !pip install pubchempy

# %%
import pubchempy as pcp

compound = pcp.get_compounds("aspirin", "name")[0]

print(compound.isomeric_smiles)
# Out:
# CC(=O)OC1=CC=CC=C1C(=O)O
# /tmp/ipykernel_8144/3828394794.py:5: PubChemPyDeprecationWarning: isomeric_smiles is deprecated: Use smiles instead
#   print(compound.isomeric_smiles)

# %%
# !pip install cirpy
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for cirpy: filename=cirpy-1.0.2-py3-none-any.whl size=7346 sha256=49dfa890c380802e93cc3483ec13d62a789900519ee02c04755191b52315e1a1
#   Stored in directory: /home/workstation-b/.cache/pip/wheels/c7/35/2b/f5d2226974fb5b1e84d53eda475d8b33a38548a6b25e32c2c0
# Successfully built cirpy
# ...

# %%
import cirpy

smiles = cirpy.resolve("aspirin", "smiles")
print(smiles)
# Out:
# CC(=O)Oc1ccccc1C(O)=O

# %%
print(cirpy.resolve("ethine","smiles"))
# Out:
# C#C

# %%
print(cirpy.resolve("ethene","smiles"))
# Out:
# C=C

# %%
print(cirpy.resolve("ethane","smiles"))
# Out:
# CC
