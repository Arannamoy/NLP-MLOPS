# %%
import pubchempy as pcp

# %%
results=pcp.get_compounds("ethanol","name")

# %%
for c in results:
    print(c.cid,c.connectivity_smiles,c.iupac_name,c.elements,c.molecular_formula,c.molecular_weight)
# Out:
# 702 CCO ethanol ['O', 'C', 'C', 'H', 'H', 'H', 'H', 'H', 'H'] C2H6O 46.07
