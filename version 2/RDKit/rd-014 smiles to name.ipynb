# %%
import cirpy

# %%
print(cirpy.resolve("CCO","names"))
# Out:
# ['ethanol', '121182-78-3', '64-17-5', '8024-45-1', '8000-16-6', '68475-56-9', '71076-86-3', '71329-38-9', 'Ethyl alcohol & water, 50%', 'Ethyl alcohol & water, 60%', 'Ethyl alcohol & water, 70%', 'Ethyl alcohol & water, 80%', 'Ethyl alcohol & water, 95%', 'Ethyl alcohol & water, 96%', 'Ethyl alcohol, anhydrous', 'Ethyl hydrate', 'Ethyl hydroxide', 'Ethylalcohol', 'Etylowy alkohol', 'Fermentation alcohol', 'Jaysol', 'Jaysol S', 'Molasses alcohol', 'NCI-C03134', 'NSC85228', 'Potato alcohol', 'SD Alchol 23-hydrogen', 'Spirits of wine', 'Spirt', 'Tecsol', 'Thanol', 'WLN: Q2', 'Absolute ethyl alcohol', '459828_ALDRICH', '02878_FLUKA', '187380_ALDRICH', '02882_FLUKA', '02883_FLUKA', '459836_ALDRICH', 'UK Industrial methylated spirit', '02884_FLUKA', 'Alcare Hand Degermer', '(C6-C9)Alkyl alcohol', 'Alcohols, C6-9', '02890_FLUKA', '34963_RIEDEL', 'D00068', 'Dehydrated ethanol (JP15)', 'Dehydrated ethanol (TN)', '02891_FLUKA', '676829_SIAL', 'Alcohols, C1-3', 'Anti-EphB1 (ELK Receptor)-CY ant
# ...
